# %%
import pandas as pd

# %%
data= pd.read_csv("multi_reg.csv")

# %%
data.head()
# Out:
#     Age  Experience    Salary
# 0  32.0         5.0   90000.0
# 1  28.0         3.0   65000.0
# 2  45.0        15.0  150000.0
# 3  36.0         7.0   60000.0
# 4  52.0        20.0  200000.0

# %%
data.shape
# Out:
# (6704, 3)

# %%
data.isnull().sum()
# Out:
# Age           2
# Experience    3
# Salary        5
# dtype: int64

# %%
data= data.dropna(subset= ["Age"])

# %%
data= data.dropna(subset= ["Experience"])

# %%
data= data.dropna(subset= ["Salary"])

# %%
data.shape
# Out:
# (6699, 3)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.pairplot(data= data)
plt.show()

# %%
sns.heatmap(data= data.corr(), annot = True)
plt.show()

# %%
x= data.iloc[:,:-1]
y = data["Salary"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size= 0.25, random_state= 42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr= LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# accuracy of model
lr.score(x_test, y_test)*100
# Out:
# 66.65705750690704

# %%
lr.coef_
# Out:
# array([-1632.11134522,  8970.03515501])

# %%
lr.intercept_
# Out:
# 97586.21489662553

# %%
# y = m1x1+m2x2+x
# y = -1632.11134522*Age +8970.03515501*Experience +97586.21489662553

# %%
lr.predict(x_test)
# Out:
# array([ 74723.50157603, 110590.48770862,  80429.31404059, ...,
#        149734.85101912, 135059.00339955, 124443.70241186])
